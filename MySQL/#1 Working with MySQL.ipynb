# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as connection

# %%
# check if the connection is established
conn = connection.connect(host="localhost",user="root", passwd="1234",use_pure=True)

# %%
cur=conn.cursor()

# %%
cur.execute("show databases")

# %%
res=cur.fetchall()
res
# Out:
# [('information_schema',),
#  ('intro_sql',),
#  ('mysql',),
#  ('performance_schema',),
#  ('test1234344',)]

# %%
res[1]
# Out:
# ('intro_sql',)

# %%
for i in res:
    print(i[0])
# Out:
# information_schema
# intro_sql
# mysql
# performance_schema
# test1234344

# %%
cur.execute("create database sudhanshu12345")

# %%
## Creating Database
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost",user="root", passwd="1234",use_pure=True)
    # check if the connection is established
    print(mydb.is_connectedc())

    query = "create database student;"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Database Created!!")
    mydb.close()

except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# 'MySQLConnection' object has no attribute 'is_connectedc'

# %%
## Show databases
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost",user="root", passwd="1234",use_pure=True)
    # check if the connection is established

    query = "SHOW DATABASES"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print(cursor.fetchall())

except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# [('information_schema',), ('intro_sql',), ('mysql',), ('performance_schema',), ('sudhanshu12345',), ('test1234344',)]

# %%
## Create Table
'''
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost", database = 'Student',user="root", passwd="mysql",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())

    query = "CREATE TABLE StudentDetails (Studentid INT(10) AUTO_INCREMENT PRIMARY KEY,FirstName VARCHAR(60)," \
            "LastName VARCHAR(60), RegistrationDate DATE,Class Varchar(20), Section Varchar(10))"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Table Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))'''
# Out:
# '\nimport mysql.connector as connection\n\ntry:\n    mydb = connection.connect(host="localhost", database = \'Student\',user="root", passwd="mysql",use_pure=True)\n    # check if the connection is established\n    print(mydb.is_connected())\n\n    query = "CREATE TABLE StudentDetails (Studentid INT(10) AUTO_INCREMENT PRIMARY KEY,FirstName VARCHAR(60),"             "LastName VARCHAR(60), RegistrationDate DATE,Class Varchar(20), Section Varchar(10))"\n\n    cursor = mydb.cursor() #create a cursor to execute queries\n    cursor.execute(query)\n    print("Table Created!!")\n    mydb.close()\nexcept Exception as e:\n    mydb.close()\n    print(str(e))'

# %%
 mydb = connection.connect(host="localhost", database = 'sudhanshu12345',user="root", passwd="1234",use_pure=True)

# %%
mydb.is_connected()
# Out:
# True

# %%
cur =mydb.cursor()
cur.execute("create table test(x1 INT(5), x2 VARCHAR(20), x3 DATE)")
mydb.close()

# %%
## Values inserted into the table
'''
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost", database = 'Student',user="root", passwd="mysql",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())
    query = "INSERT INTO StudentDetails VALUES ('1132','Sachin','Kumar','1997-11-11','Eleventh','A')"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Values inserted into the table!!")
    mydb.commit()
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
'''
# Out:
# '\nimport mysql.connector as connection\n\ntry:\n    mydb = connection.connect(host="localhost", database = \'Student\',user="root", passwd="mysql",use_pure=True)\n    # check if the connection is established\n    print(mydb.is_connected())\n    query = "INSERT INTO StudentDetails VALUES (\'1132\',\'Sachin\',\'Kumar\',\'1997-11-11\',\'Eleventh\',\'A\')"\n\n    cursor = mydb.cursor() #create a cursor to execute queries\n    cursor.execute(query)\n    print("Values inserted into the table!!")\n    mydb.commit()\n    mydb.close()\nexcept Exception as e:\n    mydb.close()\n    print(str(e))\n'

# %%
 mydb = connection.connect(host="localhost", database = 'sudhanshu12345',user="root", passwd="1234",use_pure=True)

# %%
cur=mydb.cursor()

# %%
cur.execute("insert into test values(4564, 'sudh', 15-05-2021)")
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12624/3176431203.py in <module>
# ----> 1 cur.execute("insert into test values(4564, 'sudh', 15-05-2021)")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
#     570             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     852         query = bytes(packet)
#     853         try:
# --> 854             result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     855         except errors.ProgrammingError as err:
# ...

# %%
cur.execute("insert into test values(4564, 'sudh', '15-05-2021')")
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12624/2814423605.py in <module>
# ----> 1 cur.execute("insert into test values(4564, 'sudh', '15-05-2021')")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
#     570             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     852         query = bytes(packet)
#     853         try:
# --> 854             result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     855         except errors.ProgrammingError as err:
# ...

# %%
cur.execute("insert into test values(4564, 'sudh', '2021-05-15')") ## yyy-mm-dd

# %%
mydb.commit()

# %%
cur.execute("insert into test values(4565, 'Vivek Kumar Verma', '2021-05-15')") ## yyy-mm-dd

# %%
mydb.commit()

# %%
cur.execute("insert into test values(4566, 'Dhruv', '2021-05-15')") ## yyy-mm-dd
cur.execute("insert into test values(4567, 'Amit', '2021-05-15')") ## yyy-mm-dd
cur.execute("insert into test values(4568, 'Prince', '2021-05-15')") ## yyy-mm-dd
cur.execute("insert into test values(4569, 'Gautam', '2021-05-15')") ## yyy-mm-dd
cur.execute("insert into test values(4570, 'Amarjeet', '2021-05-15')") ## yyy-mm-dd
cur.execute("insert into test values(4571, 'Ashish', '2021-05-15')")## yyy-mm-dd
cur.execute("insert into test values(4572, 'Pravin', '2021-05-15')") ## yyy-mm-dd
cur.execute("insert into test values(4573, 'Sajan', '2021-05-15')") ## yyy-mm-dd
cur.execute("insert into test values(4574, 'Devendra', '2021-05-15')") ## yyy-mm-dd

# %%
mydb.commit()

# %%
## Select from DB
'''
import mysql.connector as connection


try:
    mydb = connection.connect(host="localhost", database = 'GlassData',user="root", passwd="mysql",use_pure=True)
    #check if the connection is established
    print(mydb.is_connected())
    query = "Select * from GlassData;"
    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    for result in cursor.fetchall():
        print(result)
    mydb.close() #close the connection


except Exception as e:
    #mydb.close()
    print(str(e))
'''
# Out:
# '\nimport mysql.connector as connection\n\n\ntry:\n    mydb = connection.connect(host="localhost", database = \'GlassData\',user="root", passwd="mysql",use_pure=True)\n    #check if the connection is established\n    print(mydb.is_connected())\n    query = "Select * from GlassData;"\n    cursor = mydb.cursor() #create a cursor to execute queries\n    cursor.execute(query)\n    for result in cursor.fetchall():\n        print(result)\n    mydb.close() #close the connection\n\n\nexcept Exception as e:\n    #mydb.close()\n    print(str(e))\n'

# %%
cur1=mydb.cursor()
cur1.execute("select * from test")

# %%
cur1.fetchall()
# Out:
# [(4564, 'sudh', datetime.date(2021, 5, 15)),
#  (4565, 'Vivek Kumar Verma', datetime.date(2021, 5, 15)),
#  (4566, 'Dhruv', datetime.date(2021, 5, 15)),
#  (4567, 'Amit', datetime.date(2021, 5, 15)),
#  (4568, 'Prince', datetime.date(2021, 5, 15)),
#  (4569, 'Gautam', datetime.date(2021, 5, 15)),
#  (4570, 'Amarjeet', datetime.date(2021, 5, 15)),
#  (4571, 'Ashish', datetime.date(2021, 5, 15)),
#  (4572, 'Pravin', datetime.date(2021, 5, 15)),
#  (4573, 'Sajan', datetime.date(2021, 5, 15)),
#  (4574, 'Devendra', datetime.date(2021, 5, 15))]

# %%
for i in cur1.fetchall():
    print(i)
# Out:
# (4564, 'sudh', datetime.date(2021, 5, 15))
# (4565, 'Vivek Kumar Verma', datetime.date(2021, 5, 15))
# (4566, 'Dhruv', datetime.date(2021, 5, 15))
# (4567, 'Amit', datetime.date(2021, 5, 15))
# (4568, 'Prince', datetime.date(2021, 5, 15))
# (4569, 'Gautam', datetime.date(2021, 5, 15))
# (4570, 'Amarjeet', datetime.date(2021, 5, 15))
# (4571, 'Ashish', datetime.date(2021, 5, 15))
# (4572, 'Pravin', datetime.date(2021, 5, 15))
# (4573, 'Sajan', datetime.date(2021, 5, 15))
# (4574, 'Devendra', datetime.date(2021, 5, 15))

# %%
cur= mydb.cursor()
cur.execute("select x1, x2 from test")

# %%
for i in cur.fetchall():
    print(i)
# Out:
# (4564, 'sudh')
# (4565, 'Vivek Kumar Verma')
# (4566, 'Dhruv')
# (4567, 'Amit')
# (4568, 'Prince')
# (4569, 'Gautam')
# (4570, 'Amarjeet')
# (4571, 'Ashish')
# (4572, 'Pravin')
# (4573, 'Sajan')
# (4574, 'Devendra')

# %%
mydb.close()

# %%
## Select into Dataframe
'''
import mysql.connector as connection
import pandas as pandas

try:

    mydb = connection.connect(host="localhost", database='GlassData', user="root", passwd="mysql", use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())
    query = "Select * from GlassData;"
    result_dataFrame = pandas.read_sql(query,mydb)
    print(result_dataFrame)

    mydb.close()  # close the connection

except Exception as e:
    #mydb.close()
    print(str(e))
'''
# Out:
# '\nimport mysql.connector as connection\nimport pandas as pandas\n\ntry:\n\n    mydb = connection.connect(host="localhost", database=\'GlassData\', user="root", passwd="mysql", use_pure=True)\n    # check if the connection is established\n    print(mydb.is_connected())\n    query = "Select * from GlassData;"\n    result_dataFrame = pandas.read_sql(query,mydb)\n    print(result_dataFrame)\n\n    mydb.close()  # close the connection\n\nexcept Exception as e:\n    #mydb.close()\n    print(str(e))\n'

# %%
 mydb = connection.connect(host="localhost", database = 'sudhanshu12345',user="root", passwd="1234",use_pure=True)

# %%
import pandas as pd

# %%
mydb

# %%
pd.read_sql("select * from sudhanshu12345.test",mydb)
# Out:
#       x1                 x2          x3
# 0   4564               sudh  2021-05-15
# 1   4565  Vivek Kumar Verma  2021-05-15
# 2   4566              Dhruv  2021-05-15
# 3   4567               Amit  2021-05-15
# 4   4568             Prince  2021-05-15
# 5   4569             Gautam  2021-05-15
# 6   4570           Amarjeet  2021-05-15
# 7   4571             Ashish  2021-05-15
# 8   4572             Pravin  2021-05-15
# 9   4573              Sajan  2021-05-15
# 10  4574           Devendra  2021-05-15

# %%
pd.read_sql("select x1,x2 from sudhanshu12345.test",mydb)
# Out:
#       x1                 x2
# 0   4564               sudh
# 1   4565  Vivek Kumar Verma
# 2   4566              Dhruv
# 3   4567               Amit
# 4   4568             Prince
# 5   4569             Gautam
# 6   4570           Amarjeet
# 7   4571             Ashish
# 8   4572             Pravin
# 9   4573              Sajan
# 10  4574           Devendra

# %%
pd.read_sql("select x1,x2 from test",mydb)
# Out:
#       x1                 x2
# 0   4564               sudh
# 1   4565  Vivek Kumar Verma
# 2   4566              Dhruv
# 3   4567               Amit
# 4   4568             Prince
# 5   4569             Gautam
# 6   4570           Amarjeet
# 7   4571             Ashish
# 8   4572             Pravin
# 9   4573              Sajan
# 10  4574           Devendra

# %%
a=pd.read_sql("select x1,x2,x3 from test",mydb)
a
# Out:
#       x1                 x2          x3
# 0   4564               sudh  2021-05-15
# 1   4565  Vivek Kumar Verma  2021-05-15
# 2   4566              Dhruv  2021-05-15
# 3   4567               Amit  2021-05-15
# 4   4568             Prince  2021-05-15
# 5   4569             Gautam  2021-05-15
# 6   4570           Amarjeet  2021-05-15
# 7   4571             Ashish  2021-05-15
# 8   4572             Pravin  2021-05-15
# 9   4573              Sajan  2021-05-15
# 10  4574           Devendra  2021-05-15

# %%
a.to_csv("mydata.csv") ## creating csv file

# %%
mydb.close()

# %%
## insert from file
'''
import mysql.connector as connection
import pandas as pandas
import csv

try:
    mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
    #check if the connection is established
    print(mydb.is_connected())
    #create a new database
    query = "Create database GlassData;"
    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Database Created!!")
    mydb.close() #close the connection

    #Establish a new connection to the database created above
    mydb = connection.connect(host="localhost", database = 'GlassData',user="root", passwd="mysql", use_pure=True)

    #create a new table to store glass data
    query = "CREATE TABLE IF NOT EXISTS GlassData (Index_Number INT(10),RI float(10,5), Na float(10,5), Mg float(10,5),Al float(10,5)," \
            " Si float(10,5), K float(10,5), Ca float(10,5), Ba float(10,5), Fe float(10,5), Class INT(5))"
    cursor = mydb.cursor()  # create a cursor to execute queries
    cursor.execute(query)
    print("Table Created!!")

    #read from the file
    with open('glass.data', "r") as f:
        next(f)
        glass_data = csv.reader(f, delimiter="\n")
        for line in enumerate(glass_data):
            for list_ in (line[1]):
                cursor.execute('INSERT INTO GlassData values ({values})'.format(values=(list_)))
    print("Values inserted!!")
    mydb.commit()
    cursor.close()
    mydb.close()

except Exception as e:
    #mydb.close()
    print(str(e))
'''
# Out:
# '\nimport mysql.connector as connection\nimport pandas as pandas\nimport csv\n\ntry:\n    mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)\n    #check if the connection is established\n    print(mydb.is_connected())\n    #create a new database\n    query = "Create database GlassData;"\n    cursor = mydb.cursor() #create a cursor to execute queries\n    cursor.execute(query)\n    print("Database Created!!")\n    mydb.close() #close the connection\n\n    #Establish a new connection to the database created above\n    mydb = connection.connect(host="localhost", database = \'GlassData\',user="root", passwd="mysql", use_pure=True)\n\n    #create a new table to store glass data\n    query = "CREATE TABLE IF NOT EXISTS GlassData (Index_Number INT(10),RI float(10,5), Na float(10,5), Mg float(10,5),Al float(10,5),"             " Si float(10,5), K float(10,5), Ca float(10,5), Ba float(10,5), Fe float(10,5), Class INT(5))"\n    cursor = mydb.cursor()  # crea
# ...

# %%
mydb = connection.connect(host="localhost", database = 'sudhanshu12345',user="root", passwd="1234",use_pure=True)
mydb

# %%
cur=mydb.cursor()
cur.execute("create table mydata(n1 int(20), n2 varchar(20), n3 date)")

# %%
data=pd.read_csv("mydata.csv")
data
# Out:
#     Unnamed: 0    x1                 x2          x3
# 0            0  4564               sudh  2021-05-15
# 1            1  4565  Vivek Kumar Verma  2021-05-15
# 2            2  4566              Dhruv  2021-05-15
# 3            3  4567               Amit  2021-05-15
# 4            4  4568             Prince  2021-05-15
# 5            5  4569             Gautam  2021-05-15
# 6            6  4570           Amarjeet  2021-05-15
# 7            7  4571             Ashish  2021-05-15
# 8            8  4572             Pravin  2021-05-15
# 9            9  4573              Sajan  2021-05-15
# 10          10  4574           Devendra  2021-05-15

# %%
data.to_sql('mydata',mydb)
# Out:
# C:\Users\thevk\anaconda3\lib\site-packages\pandas\core\generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     558                 if psub.remaining != 0:
# --> 559                     raise errors.ProgrammingError(
#     560                         "Not all parameters were used in the SQL statement")
#
# ProgrammingError: Not all parameters were used in the SQL statement
#
# ...

# %%
data1= pd.read_sql('select * from test',mydb)

# %%
data1.to_sql('mydata1', mydb)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     558                 if psub.remaining != 0:
# --> 559                     raise errors.ProgrammingError(
#     560                         "Not all parameters were used in the SQL statement")
#
# ProgrammingError: Not all parameters were used in the SQL statement
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12624/1701147374.py in <module>
# ----> 1 data1.to_sql('mydata1', mydb)
#
# ...

# %%
mydb.close()

# %%
mydb = connection.connect(host="localhost", database = 'sudhanshu12345',user="root", passwd="1234",use_pure=True)
mydb

# %%
import mysql.connector as connection
import pandas as pandas
import csv

# %%
curr= mydb.cursor()
curr.execute("CREATE TABLE sudhanshu12345.GlassData1 (Index_Number INT(10),RI float(10,5), Na float(10,5), Mg float(10,5),Al float(10,5)," \
            " Si float(10,5), K float(10,5), Ca float(10,5), Ba float(10,5), Fe float(10,5), Class INT(5))")

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is F6A3-A1A3
#
#  Directory of D:\Ineuron\Programs\FSDS\Previous Batch Programs\#2 DataBase
#
# 01-06-2022  10:51            76,435 #1 Working with MySQL.ipynb
# 01-06-2022  10:51    <DIR>          .
# 01-06-2022  10:51    <DIR>          ..
# 31-05-2022  06:57    <DIR>          .ipynb_checkpoints
# 28-01-2022  00:22            11,941 glass.data
# 01-06-2022  10:45               307 mydata.csv
#                3 File(s)         88,683 bytes
#                3 Dir(s)  577,817,026,560 bytes free

# %%
with open('glass.data',"r") as data:
    data_csv= csv.reader(data, delimiter="\n")
    print(data_csv)

# %%
with open('glass.data',"r") as data:
    data_csv= csv.reader(data, delimiter="\n")
    print(data_csv)
    for i in data_csv:
        print(i)
# Out:
# ...
# ['index,RI,Na,Mg,Al,Si,K,Ca,Ba,Fe,Class']
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1']
# ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1']
# ...

# %%
with open('glass.data',"r") as data:
    data_csv= csv.reader(data, delimiter="\n")
    print(data_csv)
    for i in enumerate(data_csv):
        print(i)
# Out:
# ...
# (0, ['index,RI,Na,Mg,Al,Si,K,Ca,Ba,Fe,Class'])
# (1, ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1'])
# (2, ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1'])
# (3, ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1'])
# (4, ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1'])
# (5, ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1'])
# (6, ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1'])
# (7, ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1'])
# (8, ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1'])
# (9, ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1'])
# (10, ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1'])
# (11, ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1'])
# (12, ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1'])
# (13, ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1'])
# (14, ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1'])
# ...

# %%
mydb = connection.connect(host="localhost", database='sudhanshu12345', user="root", passwd="1234", use_pure=True)
cur= mydb.cursor()
with open('glass.data',"r") as data:
    next(data)
    data_csv= csv.reader(data, delimiter="\n")
    print(data_csv)
    for i in enumerate(data_csv):
        print(i)
        for j in i[1]:
            cur.execute('insert into sudhanshu12345.GlassData1 values ({data})'.format(data=(j)))
    print("all the data inserted")
mydb.commit()
# Out:
# ...
# (0, ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1'])
# (1, ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1'])
# (2, ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1'])
# (3, ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1'])
# (4, ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1'])
# (5, ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1'])
# (6, ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1'])
# (7, ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1'])
# (8, ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1'])
# (9, ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1'])
# (10, ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1'])
# (11, ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1'])
# (12, ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1'])
# (13, ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1'])
# (14, ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1'])
# ...

# %%
mydb = connection.connect(host="localhost", database='sudhanshu12345', user="root", passwd="1234", use_pure=True)
cur= mydb.cursor()
with open('glass.data',"r") as data:
    next(data)
    data_csv= csv.reader(data, delimiter="\n")
    print(data_csv)
    for i in enumerate(data_csv):
        print(i)
        for j in i[1]:
            print(type(j))
            cur.execute('insert into sudhanshu12345.GlassData1 values ({data})'.format(data=(j)))
    print("all the data inserted")
mydb.commit()
# Out:
# ...
# (0, ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1'])
# <class 'str'>
# (1, ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1'])
# <class 'str'>
# (2, ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1'])
# <class 'str'>
# (3, ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1'])
# <class 'str'>
# (4, ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1'])
# <class 'str'>
# (5, ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1'])
# <class 'str'>
# (6, ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1'])
# <class 'str'>
# (7, ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1'])
# <class 'str'>
# (8, ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1'])
# <class 'str'>
# (9, ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1'])
# <class 'str'>
# (10, ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1'])
# <class 'str'>
# (11, ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1'])
# <class 'str'>
# ...

# %%
mydb = connection.connect(host="localhost", database='sudhanshu12345', user="root", passwd="1234", use_pure=True)
cur= mydb.cursor()
with open('glass.data',"r") as data:
    next(data)
    data_csv= csv.reader(data, delimiter="\n")
    print(data_csv)
    for j in data_csv:
        print(j)
print("all the data inserted")
mydb.commit()
# Out:
# ...
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1']
# ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1']
# ['16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1']
# ...

# %%
mydb = connection.connect(host="localhost", database='sudhanshu12345', user="root", passwd="1234", use_pure=True)
cur= mydb.cursor()
with open('glass.data',"r") as data:
    next(data)
    data_csv= csv.reader(data, delimiter="\n")
    print(data_csv)
    for j in data_csv:
        print(type(j))
print("all the data inserted")
mydb.commit()
# Out:
# ...
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# ...

# %%
mydb = connection.connect(host="localhost", database='sudhanshu12345', user="root", passwd="1234", use_pure=True)
cur= mydb.cursor()
with open('glass.data',"r") as data:
    next(data)
    data_csv= csv.reader(data, delimiter="\n")
    print(data_csv)
    for j in data_csv:
        print(type(str(j)))
        print(j)
        ##cur.execute('insert into sudhanshu12345.GlassData1 values ({data})'.format(data=(str(j))))
    print("all the data inserted")
mydb.commit()
# Out:
# ...
# <class 'str'>
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# <class 'str'>
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# <class 'str'>
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# <class 'str'>
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# <class 'str'>
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# <class 'str'>
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# <class 'str'>
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# <class 'str'>
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# <class 'str'>
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# <class 'str'>
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# <class 'str'>
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# <class 'str'>
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# <class 'str'>
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ...

# %%
mydb = connection.connect(host="localhost", database='sudhanshu12345', user="root", passwd="1234", use_pure=True)
cur= mydb.cursor()
with open('glass.data',"r") as data:
    next(data)
    data_csv= csv.reader(data, delimiter="\n")
    print(data_csv)
    for j in data_csv:
        print(type(str(j)))
        print(j)
        cur.execute('insert into sudhanshu12345.GlassData1 values ({data})'.format(data=(str(j[0]))))
    print("all the data inserted")
mydb.commit()
# Out:
# ...
# <class 'str'>
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# <class 'str'>
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# <class 'str'>
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# <class 'str'>
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# <class 'str'>
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# <class 'str'>
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# <class 'str'>
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# <class 'str'>
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# <class 'str'>
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# <class 'str'>
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# <class 'str'>
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# <class 'str'>
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# <class 'str'>
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ...

# %%
mydb = connection.connect(host="localhost", database='sudhanshu12345', user="root", passwd="1234", use_pure=True)
cur= mydb.cursor()
with open('glass.data',"r") as data:
    next(data)
    data_csv= csv.reader(data, delimiter="\n")
    print(data_csv)
    for j in data_csv:
        print(type(str(j)))
        print(j)
        cur.execute('insert into sudhanshu12345.GlassData1 values (j[0])')
    print("all the data inserted")
mydb.commit()
# Out:
# ...
# <class 'str'>
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12624/420220446.py in <module>
#       8         print(type(str(j)))
#       9         print(j)
# ---> 10         cur.execute('insert into sudhanshu12345.GlassData1 values (j[0])')
#      11     print("all the data inserted")
#      12 mydb.commit()
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
#     570             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
# ...

# %%
mydb = connection.connect(host="localhost", database='sudhanshu12345', user="root", passwd="1234", use_pure=True)
cur= mydb.cursor()
with open('glass.data',"r") as data:
    next(data)
    data_csv= csv.reader(data, delimiter="\n")
    print(data_csv)
    for j in data_csv:
        print(type(str(j)))
        print(j)
        cur.execute('insert into sudhanshu12345.GlassData1 values str((j[0]))')
    print("all the data inserted")
mydb.commit()
# Out:
# ...
# <class 'str'>
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12624/2208413551.py in <module>
#       8         print(type(str(j)))
#       9         print(j)
# ---> 10         cur.execute('insert into sudhanshu12345.GlassData1 values str((j[0]))')
#      11     print("all the data inserted")
#      12 mydb.commit()
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
#     570             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
# ...

# %%
## Delete from table
'''
import mysql.connector as connection

try:

    mydb = connection.connect(host="localhost", database='Student', user="root", passwd="mysql", use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())
    query = "DELETE FROM studentdetails WHERE Studentid = 1122"
    cursor = mydb.cursor()  # create a cursor to execute queries
    cursor.execute(query)
    mydb.commit()

    #let's check if the value is updated in the table.
    query = "Select * from studentdetails where Studentid=1122;"
    cursor = mydb.cursor()  # create a cursor to execute queries
    cursor.execute(query)
    for result in cursor.fetchall():
        print(result)

    mydb.close()  # close the connection

except Exception as e:
    #mydb.close()
    print(str(e))
'''
# Out:
# '\nimport mysql.connector as connection\n\ntry:\n\n    mydb = connection.connect(host="localhost", database=\'Student\', user="root", passwd="mysql", use_pure=True)\n    # check if the connection is established\n    print(mydb.is_connected())\n    query = "DELETE FROM studentdetails WHERE Studentid = 1122"\n    cursor = mydb.cursor()  # create a cursor to execute queries\n    cursor.execute(query)\n    mydb.commit()\n\n    #let\'s check if the value is updated in the table.\n    query = "Select * from studentdetails where Studentid=1122;"\n    cursor = mydb.cursor()  # create a cursor to execute queries\n    cursor.execute(query)\n    for result in cursor.fetchall():\n        print(result)\n\n    mydb.close()  # close the connection\n\nexcept Exception as e:\n    #mydb.close()\n    print(str(e))\n'

# %%
mydb = connection.connect(host="localhost", database = 'sudhanshu12345',user="root", passwd="1234",use_pure=True)
mydb

# %%
mydb = connection.connect(host="localhost", database='sudhanshu12345', user="root", passwd="1234", use_pure=True)
# check if the connection is established
print(mydb.is_connected())
query = "DELETE FROM test WHERE x1 = 4564"
cursor = mydb.cursor()  # create a cursor to execute queries
cursor.execute(query)
mydb.commit()
# Out:
# True

# %%
mydb.close()

# %%
## Update Table
'''
import mysql.connector as connection
import pandas as pandas

try:

    mydb = connection.connect(host="localhost", database='Student', user="root", passwd="mysql", use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())
    query = "UPDATE studentdetails SET FirstName = 'Kumar', LastName = 'Gaurav' WHERE Studentid = 1122"
    cursor = mydb.cursor()  # create a cursor to execute queries
    cursor.execute(query)
    mydb.commit()

    #let's check if the value is updated in the table.
    query = "Select * from studentdetails where Studentid=1122;"
    cursor = mydb.cursor()  # create a cursor to execute queries
    cursor.execute(query)
    for result in cursor.fetchall():
        print(result)

    mydb.close()  # close the connection

except Exception as e:
    #mydb.close()
    print(str(e))
'''
# Out:
# '\nimport mysql.connector as connection\nimport pandas as pandas\n\ntry:\n\n    mydb = connection.connect(host="localhost", database=\'Student\', user="root", passwd="mysql", use_pure=True)\n    # check if the connection is established\n    print(mydb.is_connected())\n    query = "UPDATE studentdetails SET FirstName = \'Kumar\', LastName = \'Gaurav\' WHERE Studentid = 1122"\n    cursor = mydb.cursor()  # create a cursor to execute queries\n    cursor.execute(query)\n    mydb.commit()\n\n    #let\'s check if the value is updated in the table.\n    query = "Select * from studentdetails where Studentid=1122;"\n    cursor = mydb.cursor()  # create a cursor to execute queries\n    cursor.execute(query)\n    for result in cursor.fetchall():\n        print(result)\n\n    mydb.close()  # close the connection\n\nexcept Exception as e:\n    #mydb.close()\n    print(str(e))\n'

# %%
mydb = connection.connect(host="localhost", database='sudhanshu12345', user="root", passwd="1234", use_pure=True)
# check if the connection is established
print(mydb.is_connected())
query = "UPDATE test SET x1 = 345454, x2 = 'Amarjeet Kumar' WHERE x1 = 4570"
cursor = mydb.cursor()  # create a cursor to execute queries
cursor.execute(query)
mydb.commit()
# Out:
# True

# %%
mydb.close()
